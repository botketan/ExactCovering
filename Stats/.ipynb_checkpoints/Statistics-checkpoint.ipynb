# %% [markdown]
# # Effect of `vivify`, `arenatype` and `cover`

# %%
import subprocess
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define the x-axis parameter and its values
x_axis_name = 'arenatype'
x_axis_param = {x_axis_name: ['1', '2', '3']}

parameter_grid = {
    'vivify': ['true', 'false'],
    'cover': ['true', 'false'],
    'eagersubsume': ['true','false'],
    'score': ['true','false'],
}


metrics_patterns = {
    'restarts': r"c restarts:\s+(\d+)",
    'conflicts': r"c conflicts:\s+(\d+)",
    'time': r"c total process time since initialization:\s+(\d+\.\d+)"
}

# %%
results = []

for fixed_arenatype in x_axis_param[x_axis_name]:
    for param_name, param_values in parameter_grid.items():
        for param_value in param_values:
            command = f"cadical problem_a1.txt --lucky=false --{x_axis_name}={fixed_arenatype} --{param_name}={param_value}"
            print(f"Running: {command}")

            # Run cadical
            result = subprocess.run(command, shell=True, capture_output=True, text=True)
            output = result.stdout


            result_data = {
                x_axis_name: fixed_arenatype,
                param_name: param_value 
            }

            # Extract metrics from the output
            for metric, pattern in metrics_patterns.items():
                match = re.search(pattern, output)
                if match:
                    result_data[metric] = float(match.group(1)) if '.' in match.group(1) else int(match.group(1))
                else:
                    result_data[metric] = None  

            results.append(result_data)


df = pd.DataFrame(results)
# Out:
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --vivify=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --vivify=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --cover=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --cover=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --eagersubsume=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --score=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=1 --score=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --vivify=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --vivify=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --cover=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --cover=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --eagersubsume=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --score=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=2 --score=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --vivify=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --vivify=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --cover=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --cover=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --eagersubsume=false
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --score=true
# Running: cadical problem_a1.txt --lucky=false --arenatype=3 --score=false

# %%
def plot_metrics(df, x_axis_param_name, metric_to_plot, grouping_param):
    plt.figure(figsize=(10, 6))

    for group_value in df[grouping_param].unique():
        subset = df[df[grouping_param] == group_value]
        
        plt.plot(subset[x_axis_param_name], subset[metric_to_plot], 
                 marker='o', linestyle='-', 
                 label=f'{grouping_param}: {group_value}')

    plt.title(f"{metric_to_plot.capitalize()} vs {x_axis_param_name.capitalize()} by {grouping_param.capitalize()} Value")
    plt.xlabel(x_axis_param_name.capitalize())
    plt.ylabel(metric_to_plot.capitalize())
    plt.xticks(subset[x_axis_param_name])
    plt.legend(title=grouping_param.capitalize())
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
plot_metrics(df, x_axis_name, 'time','vivify')

# %%
plot_metrics(df, x_axis_name, 'time','cover')

# %%
plot_metrics(df, x_axis_name, 'time','eagersubsume')

# %%
plot_metrics(df, x_axis_name, 'time','score')

# %%
def compute_sat(param, values):
    results = []
    for value in values:
        command = f"cadical problem_a1.txt --lucky=false --{param}={value} --arenatype=3 --vivify=false --eagersubsume=true"
        print(f"Running: {command}")

        # Run cadical
        result = subprocess.run(command, shell=True, capture_output=True, text=True)        
        output = result.stdout

        # Check if the problem is SAT or UNSAT
        sat = "s SATISFIABLE" in output
        unsat = "s UNSATISFIABLE" in output

        if unsat:
            print(f"Waring: The problem is UNSAT for {param}={value}")

        result_data = {
            param: value
        }

        # Extract metrics from the output
        for metric, pattern in metrics_patterns.items():
            match = re.search(pattern, output)
            if match:
                result_data[metric] = float(match.group(1)) if '.' in match.group(1) else int(match.group(1))
            else:
                result_data[metric] = None
    
        results.append(result_data)
    
    return pd.DataFrame(results)

# %%
def plot_sat(df, param, metric_to_plot):
    plt.figure(figsize=(10, 6))
    plt.plot(df[metric_to_plot], df[param], marker='o', linestyle='-')
    plt.title(f"{param.capitalize()} vs {metric_to_plot.capitalize()}")
    plt.xlabel(metric_to_plot.capitalize())
    plt.ylabel(param.capitalize())
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
params = {
    'flushfactor': range(1,1001,9),
    'scorefactor': range(500,1001,10)
}

for param, values in params.items():
    df_param = compute_sat(param, values)
    df = pd.concat([df, df_param])
# Out:
# Running: cadical problem_a1.txt --lucky=false --flushfactor=1 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=10 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=19 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=28 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=37 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=46 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=55 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=64 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=73 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=82 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=91 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=100 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=109 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=118 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=127 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=136 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=145 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=154 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=163 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=172 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=181 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=190 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=199 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=208 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=217 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=226 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=235 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=244 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=253 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=262 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=271 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=280 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=289 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=298 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=307 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=316 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=325 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=334 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=343 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=352 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=361 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=370 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=379 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=388 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=397 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=406 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=415 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=424 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=433 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=442 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=451 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=460 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=469 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=478 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=487 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=496 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=505 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=514 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=523 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=532 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=541 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=550 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=559 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=568 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=577 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=586 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=595 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=604 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=613 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=622 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=631 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=640 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=649 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=658 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=667 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=676 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=685 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=694 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=703 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=712 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=721 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=730 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=739 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=748 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=757 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=766 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=775 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=784 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=793 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=802 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=811 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=820 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=829 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=838 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=847 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=856 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=865 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=874 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=883 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=892 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=901 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=910 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=919 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=928 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=937 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=946 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=955 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=964 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=973 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=982 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=991 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --flushfactor=1000 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=500 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=510 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=520 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=530 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=540 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=550 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=560 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=570 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=580 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=590 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=600 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=610 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=620 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=630 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=640 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=650 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=660 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=670 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=680 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=690 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=700 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=710 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=720 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=730 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=740 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=750 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=760 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=770 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=780 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=790 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=800 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=810 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=820 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=830 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=840 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=850 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=860 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=870 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=880 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=890 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=900 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=910 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=920 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=930 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=940 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=950 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=960 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=970 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=980 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=990 --arenatype=3 --vivify=false --eagersubsume=true
# Running: cadical problem_a1.txt --lucky=false --scorefactor=1000 --arenatype=3 --vivify=false --eagersubsume=true

# %%
plot_sat(df, 'time', 'flushfactor')

# %%
plot_sat(df, 'time', 'scorefactor')
